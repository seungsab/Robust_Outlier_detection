# %% [markdown]
# ## **[Basic Example - Robust PCA](https://nbviewer.org/github/dlegor/rad/blob/master/notebooks/Examples_and_Tests-rPCA.ipynb)**
#
# Examples
#
# - Reviewed functions and behavior with sunspot dataset.
# - Nextflix Tests
#
# In this notebook I only make test of Robust PCA.

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
sunspots=pd.read_table("http://www.sidc.be/silso/INFO/snmtotcsv.php",header=None,sep=';')

# %%
sunspots.iloc[:,3].plot(figsize=(15,10),title='Sunspots')
# Out:
# <Axes: title={'center': 'Sunspots'}>

# %%
TimeSerie=sunspots.iloc[:,3]
TimeSerie.head()
# Out:
# 0     96.7
# 1    104.3
# 2    116.7
# 3     92.8
# 4    141.7
# Name: 3, dtype: float64
